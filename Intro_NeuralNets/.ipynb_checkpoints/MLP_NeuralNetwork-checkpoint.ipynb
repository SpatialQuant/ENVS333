# %% [markdown]
# # Introduction to Artificial Neural Networks (ANNs)

# %% [markdown]
# ## What are Artificial Neural Networks
# * Computational/Mathematical models inspired by biological neural networks
# * Predictions are derived through a process of "learning" of input/output patterns contained in neurons
# * Neurons are organized in layers

# %% [markdown]
# ### Biological Neural Network

# %%
from IPython.display import Image 
Image("C:\\Users\\Laptop\\DroneCourse\\ENVS333\Intro_NeuralNets\images\img1.gif")

# %%
Image("C:\\Users\\Laptop\\DroneCourse\\ENVS333\Intro_NeuralNets\images\Test.gif")

# %% [markdown]
# ### The Perceptron
# * developed by Dr. Frank Rosenblatt in 1957
# * considered the first machine learning algorithim designed to mimic the architecture of a biological neural network
# * led to the development of the Mark 1 Perceptron

# %%
from IPython.display import Image 
Image("C:\\Users\\Laptop\\DroneCourse\\ENVS333\Intro_NeuralNets\images\Capture.gif")

# %%
Image("C:\\Users\\Laptop\\DroneCourse\\ENVS333\Intro_NeuralNets\images\percep.gif")

# %%
Image("C:\\Users\\Laptop\\DroneCourse\\ENVS333\Intro_NeuralNets\images\stepfunction.gif")

# %% [markdown]
# ### Multilayer perceptrons (Backpropagation Neural Networks)
# * developed in the 1980s
# * contains multiple layers (including one or more hidden layers)
# * considered to be non-linear classification models

# %%
Image("C:\\Users\\Laptop\\DroneCourse\\ENVS333\Intro_NeuralNets\images\mlp.png")

# %% [markdown]
# ### Training Phase of a Neural Network

# %%
Image("C:\\Users\\Laptop\\DroneCourse\\ENVS333\\Intro_NeuralNets\\images\\nntrain1.gif")

# %% [markdown]
# ### The Sigmoid Function

# %%
Image("C:\\Users\\Laptop\\DroneCourse\\ENVS333\\Intro_NeuralNets\\images\\sigmoidfunction.gif")

# %% [markdown]
# ### How is Error Calculated?
# * Using stochastic gradient descent (SGD)
# * Cue Dr. McKenna

# %% [markdown]
# ###  Common Metrics for Evaluating Error

# %% [markdown]
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$

# %%
# define true and predicted response values
true = [100, 50, 30, 20]
pred = [90, 50, 50, 30]

# %%
# calculate MSE by hand
print((10**2 + 0**2 + 20**2 + 10**2)/4.)
# Out:
# 150.0

# %% [markdown]
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$

# %%
# calculate RMSE by hand
import numpy as np
print(np.sqrt((10**2 + 0**2 + 20**2 + 10**2)/4.))
# Out:
# 12.24744871391589

# %% [markdown]
# ### Testing Phase of a Neural Network

# %%
Image("C:\\Users\\Laptop\\DroneCourse\\ENVS333\\Intro_NeuralNets\\images\\nntest1.gif")

# %% [markdown]
# ### Neural Network Classification of the Iris Dataset

# %%
Image("C:\\Users\\Laptop\\DroneCourse\\ENVS333\\Intro_NeuralNets\\images\\irisNN.png")

# %% [markdown]
# # [Create Neural Network Architectures](http://alexlenail.me/NN-SVG/index.html)
# ## [(Courtesy of ALEXANDER LENAIL)](http://alexlenail.me/)
